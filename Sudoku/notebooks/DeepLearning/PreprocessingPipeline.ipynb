# %% [markdown]
# # Image Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image
import cv2
import os
from torchvision import transforms
import torch
import pickle
from random import shuffle

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import cv2
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from torch import optim
# %matplotlib inline

# %%
(Image(filename='white_img6.png'))

# %% [markdown]
# ## Read in the image:

# %%
filename = 'white_img6.png'
img = cv2.imread(filename)

# %%
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
W = 1000
heigh, width, depth = img.shape
imgScale = W/width
newX, newY = img.shape[1]*imgScale, img.shape[0]*imgScale
new_img = cv2.resize(img, (int(newX), int(newY)))
cv2.imshow("Show by CV2", new_img)
cv2.waitKey(0)
cv2.imwrite('resize_white_img.png', new_img)
plt.imshow(new_img)

# %%
invert_img = cv2.bitwise_not(new_img)
#cv2.imshow("invert1", invert_img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
rows = [(15,125), (125,225), (235,335), (340,440), (455,555), (570,670), (680,780), (775,875), (890,990)]
columns = [(30,130), (130,230), (240,340), (355,455), (455,555), (565,665), (670,770), (800,900),(890,990)]
images_list = []
for unit in rows:
    for units in columns:
        images_list.append(invert_img[unit[0]:unit[1], units[0]:units[1]])

# %% [markdown]
# images_list = []
# for unit in rows:
#     for units in columns:
#         images_list.append(invert_img[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(images_list[0])

# %% [markdown]
# ### To save the inverted and preprocessed images to local folder:

# %%
# for i in range(len(images_list)):
#    if i <= 9:
#        cv2.imwrite("0"+f"{i}_flip.png", images_list[i])
#    else:
#        cv2.imwrite(f"{i}_flip.png", images_list[i])

# %%
# for i in range(len(images_list)):
#    cv2.imwrite(f"0{i}_flip.png", images_list[i])

# cv2.imwrite("flip_img81.png", images_list[80])

# %%
# To pull in the images from the local folder, and prepare them to be passed onto the model:

# %%
final_images = []
for i in range(len(images_list)):
#    img_array = cv2.imread(os.path.join(IMG_DIR, images))
    img_array = cv2.cvtColor(images_list[i], cv2.COLOR_BGR2GRAY)
    resize_img = cv2.resize(img_array, (28,28))
    final_images.append(resize_img)

# %%
plt.imshow(final_images[0]) # 47, 57, 69,

# %%
type(final_images[2])
# Out:
# numpy.ndarray

# %%
final_images[0][0].dtype
# Out:
# dtype('uint8')

# %%
#final_images[2] = final_images[2].astype(float)

# %% [markdown]
# ## How to save?

# %%
plt.imshow(np.full_like(final_images[5], 0))

# %%
plt.imshow(final_images[1])

# %% [markdown]
# # Creating tuples

# %%
plt.imshow(new_img)

# %%
plt.imshow(final_images[76])

# %%
copy_img41_1 = [(np.copy([final_images[8]]), 1) for i in range(20)] # values is the image
copy_img41_2 = [(np.copy([final_images[13]]), 1) for i in range(20)]
copy_img41_3 = [(np.copy([final_images[33]]), 1) for i in range(20)]
copy_img41_4 = [(np.copy([final_images[48]]), 1) for i in range(20)]
copy_img41_5 = [(np.copy([final_images[68]]), 1) for i in range(20)]

# %%
copy_img41_1.extend(copy_img41_2)
copy_img41_1.extend(copy_img41_3)
copy_img41_1.extend(copy_img41_4)
copy_img41_1.extend(copy_img41_5)
len(copy_img41_1)
# Out:
# 100

# %%
copy_img42_1 = [(np.copy([final_images[15]]), 2) for i in range(20)]
copy_img42_2 = [(np.copy([final_images[32]]), 2) for i in range(20)]
copy_img42_3 = [(np.copy([final_images[61]]), 2) for i in range(20)]
copy_img42_4 = [(np.copy([final_images[63]]), 2) for i in range(20)]
# copy_img2_5 = [(np.copy(final_images[60]), 2) for i in range(20)]
# copy_img2_6 = [(np.copy(final_images[66]), 2) for i in range(20)]

# %%
copy_img42_1.extend(copy_img42_2)
copy_img42_1.extend(copy_img42_3)
copy_img42_1.extend(copy_img42_4)

# %%
copy_img43_1 = [(np.copy([final_images[11]]), 3) for i in range(20)]
copy_img43_2 = [(np.copy([final_images[24]]), 3) for i in range(20)]
copy_img43_3 = [(np.copy([final_images[46]]), 3) for i in range(20)]
copy_img43_4 = [(np.copy([final_images[70]]), 3) for i in range(20)]
copy_img43_5 = [(np.copy([final_images[72]]), 3) for i in range(20)]
#copy_img3_6 = [(np.copy(final_images[66]), 3) for i in range(20)]

# %%
copy_img43_1.extend(copy_img43_2)
copy_img43_1.extend(copy_img43_3)
copy_img43_1.extend(copy_img43_4)
copy_img43_1.extend(copy_img43_5)
len(copy_img43_1)
# Out:
# 100

# %%
plt.imshow(new_img)

# %%
copy_img44_1 = [(np.copy([final_images[34]]), 4) for i in range(20)]
copy_img44_2 = [(np.copy([final_images[60]]), 4) for i in range(20)]
copy_img44_3 = [(np.copy([final_images[74]]), 4) for i in range(20)]
#copy_img4_4 = [(np.copy(final_images[37]), 4) for i in range(20)]
#copy_img4_5 = [(np.copy(final_images[60]), 4) for i in range(20)]
#copy_img4_6 = [(np.copy(final_images[66]), 4) for i in range(20)]

# %%
copy_img44_1.extend(copy_img44_2)
copy_img44_1.extend(copy_img44_3)
# copy_img44_1.extend(copy_img44_4)
len(copy_img44_1)
# Out:
# 60

# %%
copy_img45_1 = [(np.copy([final_images[0]]), 5) for i in range(20)]
copy_img45_2 = [(np.copy([final_images[42]]), 5) for i in range(20)]
copy_img45_3 = [(np.copy([final_images[62]]), 5) for i in range(20)]
copy_img45_4 = [(np.copy(final_images[76]), 5) for i in range(20)]
# copy_img35_5 = [(np.copy(final_images[60]), 5) for i in range(20)]
# copy_img25_6 = [(np.copy(final_images[66]), 5) for i in range(20)]

# %%
copy_img45_1.extend(copy_img45_2)
copy_img45_1.extend(copy_img45_3)
copy_img45_1.extend(copy_img45_4)
len(copy_img45_1)
# Out:
# 80

# %%
plt.imshow(final_images[35])

# %%
copy_img46_1 = [(np.copy([final_images[35]]), 6) for i in range(20)]
copy_img46_2 = [(np.copy([final_images[40]]), 6) for i in range(20)]
copy_img46_3 = [(np.copy([final_images[54]]), 6) for i in range(20)]
#copy_img36_4 = [(np.copy([final_images[80]]), 6) for i in range(20)]
#copy_img6_5 = [(np.copy(final_images[60]), 6) for i in range(20)]
#copy_img6_6 = [(np.copy(final_images[66]), 6) for i in range(20)]

# %%
copy_img46_1.extend(copy_img46_2)
copy_img46_1.extend(copy_img46_3)
len(copy_img46_1)
# copy_img26_1.extend(copy_img26_4)
# Out:
# 60

# %%
plt.imshow(new_img)

# %%
plt.imshow(final_images[39])

# %%
copy_img47_1 = [(np.copy([final_images[6]]), 7) for i in range(20)]
copy_img47_2 = [(np.copy([final_images[14]]), 7) for i in range(20)]
copy_img47_3 = [(np.copy([final_images[49]]), 7) for i in range(20)]
copy_img47_4 = [(np.copy([final_images[57]]), 7) for i in range(20)]
copy_img47_5 = [(np.copy([final_images[71]]), 7) for i in range(20)]
# copy_img27_6 = [(np.copy([final_images[57]]), 7) for i in range(20)]
# copy_img27_7 = [(np.copy([final_images[69]]), 7) for i in range(20)]

# %%
copy_img47_1.extend(copy_img47_2)
copy_img47_1.extend(copy_img47_3)
copy_img47_1.extend(copy_img47_4)
copy_img47_1.extend(copy_img47_5)
# copy_img27_1.extend(copy_img27_6)
# copy_img27_1.extend(copy_img27_7)
len(copy_img47_1)
# Out:
# 100

# %%
copy_img48_1 = [(np.copy([final_images[23]]), 8) for i in range(20)]
copy_img48_2 = [(np.copy([final_images[39]]), 8) for i in range(20)]
# copy_img38_3 = [(np.copy([final_images[49]]), 8) for i in range(20)]
# copy_img38_4 = [(np.copy([final_images[68]]), 8) for i in range(20)]
#copy_img38_5 = [(np.copy(final_images[68]), 8) for i in range(20)]
#copy_img8_6 = [(np.copy(final_images[66]), 8) for i in range(20)]

# %%
copy_img48_1.extend(copy_img48_2)
# copy_img38_1.extend(copy_img38_3)
# copy_img38_1.extend(copy_img38_4)
len(copy_img48_1)
# Out:
# 40

# %%
plt.imshow(new_img)

# %%
copy_img1_1[0][0].shape
# Out:
# (1, 28, 28)

# %%
copy_img49_1 = [(np.copy([final_images[22]]), 9) for i in range(22)]
copy_img49_2 = [(np.copy([final_images[30]]), 9) for i in range(22)]
copy_img49_3 = [(np.copy([final_images[55]]), 9) for i in range(22)]
copy_img49_4 = [(np.copy([final_images[69]]), 9) for i in range(22)]
#copy_img29_5 = [(np.copy([final_images[77]]), 9) for i in range(22)]
#copy_img29_6 = [(np.copy(final_images[66]), 9) for i in range(20)]

# %%
copy_img49_1.extend(copy_img49_2)
copy_img49_1.extend(copy_img49_3)
copy_img49_1.extend(copy_img49_4)
# copy_img39_1.extend(copy_img39_5)
len(copy_img49_1)
# Out:
# 88

# %%
copy_img41_1.extend(copy_img42_1)
copy_img41_1.extend(copy_img43_1)
copy_img41_1.extend(copy_img44_1)
copy_img41_1.extend(copy_img45_1)
copy_img41_1.extend(copy_img46_1)
copy_img41_1.extend(copy_img47_1)
copy_img41_1.extend(copy_img48_1)
copy_img41_1.extend(copy_img49_1)

# %%
len(copy_img41_1)
# Out:
# 708

# %%
shuffle(copy_img41_1)

# %%
first_list = copy_img1_1

# %%
second_list = copy_img21_1
len(second_list)
# Out:
# 610

# %%
third_list = copy_img31_1
len(third_list)
# Out:
# 668

# %%
fourth_list = copy_img41_1
len(fourth_list)
# Out:
# 708

# %%
# plt.imshow(second_list[0][0])

# %%
first_list.extend(second_list)
first_list.extend(third_list)
first_list.extend(fourth_list)
len(first_list)
# Out:
# 8564

# %%
#first_list = copy_img1_1
print(len(first_list))
len(second_list)
#type(first_list)
# Out:
# 620
# 610

# %%
# helper.imshow(first_list[0][0])
first_list[0][1]
# Out:
# 2

# %%
transform = transforms.ToTensor()

# %%
first_list[2000][1]
# Out:
# 8

# %%
tensors = []
for num in first_list:
    tensors.append((transform(num[0]).view(1,28,28).type(torch.FloatTensor), num[1]))
        
#    for i, b in num: #num represents the tuple itself
#        i = transform(i)
#        tensors.append((i,b))
#        transform(copy_img1_1[i][b])

# %%
type(tensors)
# Out:
# list

# %%
type(tensors[0])
# Out:
# tuple

# %%
(tensors[200][0]).dtype
# Out:
# torch.float32

# %%
tensors[20][0].shape # 1 is the number of images, 1 is the layers i.e. RGB vs Gray and 28*28 is the size
# Out:
# torch.Size([1, 1, 28, 28])

# %%
train_loader = (n for n in tensors)

# %%
batch = next(iter(train_loader))

# %%
images, labels = batch

# %%
len(batch), type(batch)
# Out:
# (2, tuple)

# %%
labels
# Out:
# 2

# %%
train_loader = torch.utils.data.DataLoader(tensors, batch_size=10, shuffle=True)

# %%
batch = next(iter(train_loader))
print('len:', len(batch))
# Out:
# len: 2

# %%
images, labels = batch

# %%
print('Types:', type(images), type(labels))
print('shapes:', images.shape, labels.shape)
# Out:
# Types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# shapes: torch.Size([10, 1, 1, 28, 28]) torch.Size([10])

# %%
labels
# Out:
# tensor([4, 2, 6, 5, 3, 3, 3, 5, 3, 3])

# %%
import torchvision

# %%
grid = torchvision.utils.make_grid(images, nrow=10)

plt.figure(figsize=(15,15))
# plt.imshow(grid)
plt.imshow(np.transpose(grid, (1,2,0)))

print('labels:', labels)
# Out:
# labels: 2

# %%
import helper

# %%
# images, label = next(iter(train_loader))
helper.imshow(images[0,:]);

# %% [markdown]
# # Models

# %% [markdown]
# We will be creating a CNN to train our model.

# %%
# Build our own network.

# %%
class ColvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1,6,3,1)
        self.conv2 = nn.Conv2d(6,16,3,1)
        self.fc1 = nn.Linear(12*4*4,120)
        self.fc2 = nn.Linear(120,84)
        self.fc3 = nn.Linear(84,9)
        
    def forward(self,X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2) # 2 is the filter size and 2 is the stride
        X = X.view(-1, 12*4*4)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
network = ConvolutionalNetwork()
network
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
# Out:
# torch.Size([6, 1, 3, 3])

# %%
train_loader = torch.utils.data.DataLoader(tensors, batch_size=10, shuffle=True)

# %%
batch = next(iter(train_loader))
print('len:', len(batch))
# Out:
# len: 2

# %%
images, labels = batch

# %%
print('Types:', type(images), type(labels))
print('shapes:', images.shape, labels.shape)
# Out:
# Types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# shapes: torch.Size([10, 1, 28, 28]) torch.Size([10])

# %%
labels
# Out:
# tensor([4, 6, 8, 5, 3, 3, 6, 3, 1, 3])

# %%
preds = model(images) # Pass Batch
loss = F.cross_entropy(preds, labels) # Calculate Loss

loss.backward() # Calculate Gradients
optimizer.step() # Update Weights

print('loss1:', loss.item())
preds = model(images)
loss = F.cross_entropy(preds, labels)
print('loss2:', loss.item())
# Out:
# loss1: 2.3268771171569824
# loss2: 2.3268771171569824

# %%
network = ConvolutionalNetwork()
optimizer = optim.Adam(network.parameters(), lr=0.01)
train_loader = torch.utils.data.DataLoader(
    tensors
    ,batch_size=100
    ,shuffle=True
)

# %%
def get_num_correct(preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()

# %%
@torch.no_grad()
def get_all_preds(model, loader):
    all_preds = torch.tensor([])
    for batch in loader:
        images, labels = batch

        preds = model(images)
        all_preds = torch.cat(
            (all_preds, preds)
            ,dim=0
        )
    return all_preds

# %%
for epoch in range(50):

    total_loss = 0
    total_correct = 0

    for batch in train_loader: # Get Batch
        images, labels = batch 

        preds = network(images) # Pass Batch
        loss = F.cross_entropy(preds, labels) # Calculate Loss

        optimizer.zero_grad()
        loss.backward() # Calculate Gradients
        optimizer.step() # Update Weights

        total_loss += loss.item()
        total_correct += get_num_correct(preds, labels)

    print(
        "epoch", epoch, 
        "total_correct:", total_correct, 
        "loss:", total_loss
    )
# Out:
# epoch 0 total_correct: 8481 loss: 1.1694975174684714
# epoch 1 total_correct: 8486 loss: 1.1526127466925118
# epoch 2 total_correct: 8482 loss: 1.1518779286261633
# epoch 3 total_correct: 8495 loss: 1.1273870562688444
# epoch 4 total_correct: 8491 loss: 1.1521692579893852
# epoch 5 total_correct: 8476 loss: 1.14989542461376
# epoch 6 total_correct: 8486 loss: 1.1400508251493875
# epoch 7 total_correct: 8488 loss: 1.1414812226905724
# epoch 8 total_correct: 8485 loss: 1.1577775950762543
# epoch 9 total_correct: 8473 loss: 1.162778301227604
# epoch 10 total_correct: 8480 loss: 1.1478625408207108
# epoch 11 total_correct: 8473 loss: 1.1585722041787676
# epoch 12 total_correct: 8488 loss: 1.1312639314935495
# epoch 13 total_correct: 8491 loss: 1.123315389282368
# epoch 14 total_correct: 7534 loss: 51.08206223753234
# epoch 15 total_correct: 7197 loss: 106.79620054876432
# epoch 16 total_correct: 8477 loss: 1.746106602367945
# epoch 17 total_correct: 8480 loss: 1.9777747295447625
# ...

# %%
IMG_DIR = 'C:/Users/Billi/repos/sudoku/images/Square4'

# %%
filenames = os.listdir(IMG_DIR)
#filenames.sort()
final_images1 = []
for images in filenames:
    img_array = cv2.imread(os.path.join(IMG_DIR, images))
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY)
    resize_img = cv2.resize(img_array, (28,28))
    final_images1.append(resize_img)

# %%
transform = transforms.ToTensor()
tensor_images1 = []
for images in final_images:
    tensors1 = torch.tensor(images, dtype=torch.float)
    tensor_images1.append(tensors1)

# %%
def convert(tensor): # always be passing in an array
    grid = []
    for i in range(len(tensor)):
        if tensor[i].mean().item() <= 22:
            grid.append(".")
        else:
            grid.append(str(network(tensor[i].view(1,1,28,28)).argmax().item()))
    return grid

# %%
convert(tensor_images1)
# Out:
# ['8',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '8',
#  '.',
#  '8',
#  '8',
#  '8',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '8',
#  '8',
#  '8',
#  '.',
#  '.',
#  '.',
#  '.',
#  '8',
#  '8',
#  '.',
#  '8',
#  '8',
#  '8',
#  '8',
#  '.',
#  '.',
#  '.',
#  '8',
#  '8',
#  '.',
#  '8',
#  '.',
#  '.',
#  '.',
#  '8',
#  '.',
#  '8',
#  '8',
#  '.',
#  '.',
#  '.',
#  '.',
#  '8',
#  '8',
#  '.',
#  '8',
#  '.',
#  '.',
#  '8',
#  '8',
#  '8',
#  '8',
#  '.',
#  '.',
#  '.',
#  '.',
#  '8',
#  '8',
#  '8',
#  '.',
#  '8',
#  '.',
#  '8',
#  '.',
#  '8',
#  '.',
#  '.',
#  '.',
#  '.']

# %%
len(tensors)
# Out:
# 8564

# %%
optimizer = optim.Adam(network.parameters(), lr=0.01)

total_loss = 0
total_correct = 0

for batch in next(iter(train_loader)): # Get Batch
    images, labels = batch 

    preds = network(images) # Pass Batch
    loss = F.cross_entropy(preds, labels) # Calculate Loss

    optimizer.zero_grad()
    loss.backward() # Calculate Gradients
    optimizer.step() # Update Weights

    total_loss += loss.item()
#    total_correct += get_num_correct(preds, labels)
    
print(
    "epoch:", 0, 
#    "total_correct:", total_correct, 
    "loss:", total_loss
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-524-3fc8cd3dce49> in <module>
#       5
#       6 for batch in next(iter(train_loader)): # Get Batch
# ----> 7     images, labels = batch
#       8
#       9     preds = network(images) # Pass Batch
#
# ValueError: too many values to unpack (expected 2)

# %%
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003)

epochs = 25
for e in range(epochs):
    running_loss = 0
    for images, labels in next(iter(train_loader)):
        # Flatten MNIST images into a 784 long vector
        images = images.view(1,28,28).argmax()
    
        # TODO: Training pass
        optimizer.zero_grad()
        
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print(f"Training loss: {running_loss/len(train_loader)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-519-79b392215dec> in <module>
#       6 for e in range(epochs):
#       7     running_loss = 0
# ----> 8     for images, labels in next(iter(train_loader)):
#       9         # Flatten MNIST images into a 784 long vector
#      10         images = images.view(1,28,28).argmax()
#
# ValueError: too many values to unpack (expected 2)

# %%
def convert(tensor): # always be passing in an array
    grid = []
    for i in range(len(tensor)):
        if tensor[i].mean().item() <= 22:
            grid.append(".")
        else:
            grid.append(str(model(tensor[i].view(1,1,28,28)).argmax().item()))
    return grid

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(5*5*16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 5*5*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
torch.manual_seed(42)
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
import time
start_time = time.time()

epochs = 5
train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        b+=1
        
        # Apply the model
        y_pred = model(X_train)  # we don't flatten X-train here
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print interim results
#        if b%600 == 0:
#            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/60000]  loss: {loss.item():10.8f}  \
#accuracy: {trn_corr.item()*100/(10*b):7.3f}%')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-578-5fbb2e54b4fe> in <module>
#      17
#      18         # Apply the model
# ---> 19         y_pred = model(X_train)  # we don't flatten X-train here
#      20         loss = criterion(y_pred, y_train)
#      21
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-574-19d49927f4f0> in forward(self, X)
#       9
#      10     def forward(self, X):
# ---> 11         X = F.relu(self.conv1(X))
#      12         X = F.max_pool2d(X, 2, 2)
#      13         X = F.relu(self.conv2(X))
#
# ...

# %%
for i in range(len(final_images)):
    if final_images[i].max() != 255:
        np.full_like(final_images[i], 0)
